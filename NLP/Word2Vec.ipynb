# %%
pip install gensim
# Out:
# Collecting gensim
#   Using cached gensim-4.4.0.tar.gz (23.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.18.5 in /Users/premkumargontrand/AITrainingFeb2026/AITrainingFeb06/lib/python3.14/site-packages (from gensim) (2.4.2)
# Collecting scipy>=1.7.0 (from gensim)
#   Using cached scipy-1.17.1-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: smart_open>=1.8.1 in /Users/premkumargontrand/AITrainingFeb2026/AITrainingFeb06/lib/python3.14/site-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /Users/premkumargontrand/AITrainingFeb2026/AITrainingFeb06/lib/python3.14/site-packages (from smart_open>=1.8.1->gensim) (2.1.1)
# Using cached scipy-1.17.1-cp314-cp314-macosx_14_0_arm64.whl (20.3 MB)
# Building wheels for collected packages: gensim
#   Building wheel for gensim (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for gensim (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [797 lines of output]
#       /private/var/folders/9w/xvbd3bbd3plcxqyvbhj_6z680000gn/T/pip-build-env-di8s8ggq/overlay/lib/python3.14/site-packages/setuptools/_distutils/dist.py:287: UserWarning: Unknown distribution option: 'test_suite'
#         warnings.warn(msg)
#       /private/var/folders/9w/xvbd3bbd3plcxqyvbhj_6z680000gn/T/pip-build-env-di8s8ggq/overlay/lib/python3.14/site-packages/setuptools/_distutils/dist.py:287: UserWarning: Unknown distribution option: 'tests_require'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-14.0-arm64-cpython-314/gensim
#       copying gensim/interfaces.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim
#       copying gensim/downloader.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim
#       copying gensim/matutils.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim
#       copying gensim/__init__.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim
#       copying gensim/utils.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim
#       copying gensim/nosy.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim
#       creating build/lib.macosx-14.0-arm64-cpython-314/gensim/similarities
#       copying gensim/similarities/docsim.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/similarities
#       copying gensim/similarities/__init__.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/similarities
#       copying gensim/similarities/nmslib.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/similarities
#       copying gensim/similarities/levenshtein.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/similarities
#       copying gensim/similarities/termsim.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/similarities
#       copying gensim/similarities/annoy.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/similarities
#       creating build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_text_analysis.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_glove2word2vec.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_parsing.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_tmdiff.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_utils.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_matutils.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_word2vec.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_segmentation.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_lsimodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_coherencemodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_miislita.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_phrases.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_tfidfmodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_poincare.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_rpmodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_corpora_hashdictionary.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_ensemblelda.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/simspeed2.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_aggregation.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/__init__.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_lee.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_big.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_translation_matrix.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/basetmtests.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_ldaseqmodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_datatype.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_similarity_metrics.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_ldamodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_nmf.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_lda_callback.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/utils.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_keyedvectors.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_corpora_dictionary.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/svd_error.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_logentropy_model.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_doc2vec.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_similarities.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_direct_confirmation.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_api.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_atmodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_corpora.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_indirect_confirmation.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_probability_estimation.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_fasttext.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_bm25model.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_scripts.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_normmodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_hdpmodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/test_sharded_corpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       copying gensim/test/simspeed.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test
#       creating build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/poincare.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/basemodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/phrases.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/ensemblelda.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/_fasttext_bin.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/word2vec.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/normmodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/translation_matrix.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/__init__.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/bm25model.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/lsimodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/rpmodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/logentropy_model.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/keyedvectors.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/lda_worker.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/fasttext.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/tfidfmodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/doc2vec.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/callbacks.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/hdpmodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/ldamulticore.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/ldaseqmodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/lsi_dispatcher.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/lda_dispatcher.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/ldamodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/nmf.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/atmodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/lsi_worker.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       copying gensim/models/coherencemodel.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/models
#       creating build/lib.macosx-14.0-arm64-cpython-314/gensim/scripts
#       copying gensim/scripts/make_wikicorpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/scripts
#       copying gensim/scripts/word2vec2tensor.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/scripts
#       copying gensim/scripts/package_info.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/scripts
#       copying gensim/scripts/benchmark.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/scripts
#       copying gensim/scripts/segment_wiki.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/scripts
#       copying gensim/scripts/__init__.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/scripts
#       copying gensim/scripts/make_wiki_online.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/scripts
#       copying gensim/scripts/make_wiki.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/scripts
#       copying gensim/scripts/make_wiki_online_nodebug.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/scripts
#       copying gensim/scripts/glove2word2vec.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/scripts
#       copying gensim/scripts/word2vec_standalone.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/scripts
#       creating build/lib.macosx-14.0-arm64-cpython-314/gensim/parsing
#       copying gensim/parsing/__init__.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/parsing
#       copying gensim/parsing/preprocessing.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/parsing
#       copying gensim/parsing/porter.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/parsing
#       creating build/lib.macosx-14.0-arm64-cpython-314/gensim/topic_coherence
#       copying gensim/topic_coherence/direct_confirmation_measure.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/topic_coherence
#       copying gensim/topic_coherence/aggregation.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/topic_coherence
#       copying gensim/topic_coherence/text_analysis.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/topic_coherence
#       copying gensim/topic_coherence/probability_estimation.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/topic_coherence
#       copying gensim/topic_coherence/__init__.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/topic_coherence
#       copying gensim/topic_coherence/indirect_confirmation_measure.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/topic_coherence
#       copying gensim/topic_coherence/segmentation.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/topic_coherence
#       creating build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/sharded_corpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/textcorpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/wikicorpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/csvcorpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/opinosiscorpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/__init__.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/malletcorpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/mmcorpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/ucicorpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/indexedcorpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/lowcorpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/bleicorpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/dictionary.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/svmlightcorpus.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       copying gensim/corpora/hashdictionary.py -> build/lib.macosx-14.0-arm64-cpython-314/gensim/corpora
#       running egg_info
#       writing gensim.egg-info/PKG-INFO
#       writing dependency_links to gensim.egg-info/dependency_links.txt
#       writing requirements to gensim.egg-info/requires.txt
#       writing top-level names to gensim.egg-info/top_level.txt
#       reading manifest file 'gensim.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       adding license file 'COPYING'
#       writing manifest file 'gensim.egg-info/SOURCES.txt'
#       /private/var/folders/9w/xvbd3bbd3plcxqyvbhj_6z680000gn/T/pip-build-env-di8s8ggq/overlay/lib/python3.14/site-packages/setuptools/command/build_py.py:215: _Warning: Package 'gensim.test.test_data' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /private/var/folders/9w/xvbd3bbd3plcxqyvbhj_6z680000gn/T/pip-build-env-di8s8ggq/overlay/lib/python3.14/site-packages/setuptools/command/build_py.py:215: _Warning: Package 'gensim.test.test_data.DTM' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.DTM' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.DTM' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.DTM' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.DTM' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /private/var/folders/9w/xvbd3bbd3plcxqyvbhj_6z680000gn/T/pip-build-env-di8s8ggq/overlay/lib/python3.14/site-packages/setuptools/command/build_py.py:215: _Warning: Package 'gensim.test.test_data.PathLineSentences' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.PathLineSentences' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.PathLineSentences' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.PathLineSentences' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.PathLineSentences' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /private/var/folders/9w/xvbd3bbd3plcxqyvbhj_6z680000gn/T/pip-build-env-di8s8ggq/overlay/lib/python3.14/site-packages/setuptools/command/build_py.py:215: _Warning: Package 'gensim.test.test_data.old_d2v_models' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.old_d2v_models' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.old_d2v_models' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.old_d2v_models' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.old_d2v_models' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /private/var/folders/9w/xvbd3bbd3plcxqyvbhj_6z680000gn/T/pip-build-env-di8s8ggq/overlay/lib/python3.14/site-packages/setuptools/command/build_py.py:215: _Warning: Package 'gensim.test.test_data.old_w2v_models' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.old_w2v_models' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.old_w2v_models' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.old_w2v_models' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.old_w2v_models' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       copying gensim/_matutils.c -> build/lib.macosx-14.0-arm64-cpython-314/gensim
#       copying gensim/_matutils.pyx -> build/lib.macosx-14.0-arm64-cpython-314/gensim
#       copying gensim/similarities/fastss.c -> build/lib.macosx-14.0-arm64-cpython-314/gensim/similarities
#       creating build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/EN.1-10.cbow1_wind5_hs0_neg10_size300_smpl1e-05.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/IT.1-10.cbow1_wind5_hs0_neg10_size300_smpl1e-05.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/OPUS_en_it_europarl_train_one2ten.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/alldata-id-10.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/atmodel_3_0_1_model -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/atmodel_3_0_1_model.expElogbeta.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/atmodel_3_0_1_model.id2word -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/atmodel_3_0_1_model.state -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/bgwiki-latest-pages-articles-shortened.xml.bz2 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/compatible-hash-true.model -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/cp852_fasttext.bin -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/crime-and-punishment.bin -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/crime-and-punishment.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/crime-and-punishment.vec -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/d2v-lee-v0.13.0 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/doc2vec_old -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/doc2vec_old_sep -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/doc2vec_old_sep.syn0_lockf.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/doc2vec_old_sep.syn1neg.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/dtm_test.dict -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/dtm_test.mm -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/ensemblelda -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/enwiki-latest-pages-articles1.xml-p000000010p000030302-shortened.bz2 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/enwiki-table-markup.xml.bz2 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/euclidean_vectors.bin -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/fasttext_old -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/fasttext_old_sep -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/fasttext_old_sep.syn0_lockf.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/fasttext_old_sep.syn1neg.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/fb-ngrams.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/ft_kv_3.6.0.model.gz -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/ft_model_2.3.0 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/head500.noblanks.cor -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/head500.noblanks.cor.bz2 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/head500.noblanks.cor_tfidf.model -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/head500.noblanks.cor_wordids.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/high_precision.kv.bin -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/high_precision.kv.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/large_tag_doc_10_iter50 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/lda_3_0_1_model -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/lda_3_0_1_model.expElogbeta.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/lda_3_0_1_model.id2word -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/lda_3_0_1_model.state -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_2_7 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_2_7.expElogbeta.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_2_7.id2word -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_2_7.state -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_3_5 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_3_5.expElogbeta.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_3_5.id2word -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_3_5.state -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/ldavowpalwabbit.dict.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/ldavowpalwabbit.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/lee.cor -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/lee_background.cor -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/lee_fasttext -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/lee_fasttext.bin -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/lee_fasttext.vec -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/lee_fasttext_new.bin -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/miIslita.cor -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/mini_newsgroup -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/model-from-gensim-3.8.0.w2v -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/nmf_model -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/non_ascii_fasttext.bin -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/old_keyedvectors_320.dat -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/pang_lee_polarity.cor -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/pang_lee_polarity_fasttext.bin -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/pang_lee_polarity_fasttext.vec -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/para2para_text1.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/para2para_text2.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/phraser-3.6.0.model -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/phraser-no-common-terms.pkl -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/phraser-no-scoring.pkl -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/phraser-scoring-str.pkl -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/phrases-3.6.0.model -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/phrases-no-common-terms.pkl -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/phrases-no-scoring.pkl -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/phrases-scoring-str.pkl -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/poincare_cp852.tsv -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/poincare_hypernyms.tsv -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/poincare_hypernyms_large.tsv -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/poincare_test_3.4.0 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/poincare_utf8.tsv -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/poincare_vectors.bin -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/pre_0_13_2_model -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/pre_0_13_2_model.state -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/pretrained.vec -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/questions-words.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/reproduce.dat -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/reproduce.dat.gz -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/similarities0-1.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/simlex999.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/small_tag_doc_5_iter50 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/test_corpus_ok.mm -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/test_corpus_small.mm -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/test_glove.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_corrupt.mm -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_no_index.mm -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_no_index.mm.bz2 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_no_index.mm.gz -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_overflow.mm -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_with_index.mm -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_with_index.mm.index -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.blei -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.blei.index -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.blei.vocab -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.low -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.low.index -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.mallet -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.mallet.index -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.mm -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.mm.index -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.svmlight -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.svmlight.index -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.uci -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.uci.index -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.uci.vocab -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.xml.bz2 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/tfidf_model.tst -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/tfidf_model.tst.bz2 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/tfidf_model_3_2.tst -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/toy-data.txt -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/toy-model-pretrained.bin -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/toy-model.bin -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/toy-model.vec -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/varembed_lee_subcorpus.cor -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/varembed_morfessor.bin -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/varembed_vectors.pkl -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/w2v-lee-v0.12.0 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/w2v_keyedvectors_load_test.modeldata -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/w2v_keyedvectors_load_test.vocab -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_3.3 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep.syn0_lockf.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep.syn1neg.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_c -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py2 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py3 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py3_4 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.neg_labels.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn0.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn0_lockf.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn1neg.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.neg_labels.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn0.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn0_lockf.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn1neg.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4 -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.neg_labels.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn0.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn0_lockf.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn1neg.npy -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       copying gensim/test/test_data/wordsim353.tsv -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data
#       creating build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data/DTM
#       copying gensim/test/test_data/DTM/ldaseq_3_0_1_model -> build/lib.macosx-14.0-arm64-cpython-314/gensim/test/test_data/DTM
# ...
#        1447 |   #define __Pyx_INCREF(r) Py_INCREF(r)
#             |                                     ^
#       /opt/homebrew/opt/python@3.14/Frameworks/Python.framework/Versions/3.14/include/python3.14/refcount.h:306:50: note: expanded from macro 'Py_INCREF'
#         306 | #  define Py_INCREF(op) Py_INCREF(_PyObject_CAST(op))
#             |                                                  ^~
#       /opt/homebrew/opt/python@3.14/Frameworks/Python.framework/Versions/3.14/include/python3.14/object.h:167:49: note: expanded from macro '_PyObject_CAST'
#         167 | #define _PyObject_CAST(op) _Py_CAST(PyObject*, (op))
#             |                                                 ^~
#       /opt/homebrew/opt/python@3.14/Frameworks/Python.framework/Versions/3.14/include/python3.14/pyport.h:37:38: note: expanded from macro '_Py_CAST'
#          37 | #define _Py_CAST(type, expr) ((type)(expr))
#             |                                      ^~~~
#       gensim/models/word2vec_inner.c:9365:38: error: no member named 'subarray' in 'struct _PyArray_Descr'
#        9365 |     __pyx_r = ((PyObject*)__pyx_v_d->subarray->shape);
#             |                           ~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:10747:3: error: no member named 'ma_version_tag' in 'PyDictObject'
#        10747 |   __Pyx_GetModuleGlobalName(__pyx_t_2, __pyx_n_s_np); if (unlikely(!__pyx_t_2)) __PYX_ERR(0, 25, __pyx_L1_error)
#              |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1714:43: note: expanded from macro '__Pyx_GetModuleGlobalName'
#        1714 |     (var) = (likely(__pyx_dict_version == __PYX_GET_DICT_VERSION(__pyx_d))) ?\
#             |              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                                                 ^
#       gensim/models/word2vec_inner.c:962:43: note: expanded from macro 'likely'
#         962 |   #define likely(x)   __builtin_expect(!!(x), 1)
#             |                                           ^
#       gensim/models/word2vec_inner.c:10762:3: error: no member named 'ma_version_tag' in 'PyDictObject'
#        10762 |   __Pyx_GetModuleGlobalName(__pyx_t_1, __pyx_n_s_fblas); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 29, __pyx_L1_error)
#              |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1714:43: note: expanded from macro '__Pyx_GetModuleGlobalName'
#        1714 |     (var) = (likely(__pyx_dict_version == __PYX_GET_DICT_VERSION(__pyx_d))) ?\
#             |              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                                                 ^
#       gensim/models/word2vec_inner.c:962:43: note: expanded from macro 'likely'
#         962 |   #define likely(x)   __builtin_expect(!!(x), 1)
#             |                                           ^
#       gensim/models/word2vec_inner.c:10780:3: error: no member named 'ma_version_tag' in 'PyDictObject'
#        10780 |   __Pyx_GetModuleGlobalName(__pyx_t_1, __pyx_n_s_fblas); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 30, __pyx_L1_error)
#              |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1714:43: note: expanded from macro '__Pyx_GetModuleGlobalName'
#        1714 |     (var) = (likely(__pyx_dict_version == __PYX_GET_DICT_VERSION(__pyx_d))) ?\
#             |              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                                                 ^
#       gensim/models/word2vec_inner.c:962:43: note: expanded from macro 'likely'
#         962 |   #define likely(x)   __builtin_expect(!!(x), 1)
#             |                                           ^
#       gensim/models/word2vec_inner.c:10798:3: error: no member named 'ma_version_tag' in 'PyDictObject'
#        10798 |   __Pyx_GetModuleGlobalName(__pyx_t_1, __pyx_n_s_fblas); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 31, __pyx_L1_error)
#              |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1714:43: note: expanded from macro '__Pyx_GetModuleGlobalName'
#        1714 |     (var) = (likely(__pyx_dict_version == __PYX_GET_DICT_VERSION(__pyx_d))) ?\
#             |              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                                                 ^
#       gensim/models/word2vec_inner.c:962:43: note: expanded from macro 'likely'
#         962 |   #define likely(x)   __builtin_expect(!!(x), 1)
#             |                                           ^
#       gensim/models/word2vec_inner.c:10816:3: error: no member named 'ma_version_tag' in 'PyDictObject'
#        10816 |   __Pyx_GetModuleGlobalName(__pyx_t_1, __pyx_n_s_fblas); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 32, __pyx_L1_error)
#              |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1714:43: note: expanded from macro '__Pyx_GetModuleGlobalName'
#        1714 |     (var) = (likely(__pyx_dict_version == __PYX_GET_DICT_VERSION(__pyx_d))) ?\
#             |              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                                                 ^
#       gensim/models/word2vec_inner.c:962:43: note: expanded from macro 'likely'
#         962 |   #define likely(x)   __builtin_expect(!!(x), 1)
#             |                                           ^
#       gensim/models/word2vec_inner.c:10834:3: error: no member named 'ma_version_tag' in 'PyDictObject'
#        10834 |   __Pyx_GetModuleGlobalName(__pyx_t_1, __pyx_n_s_fblas); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 33, __pyx_L1_error)
#              |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1714:43: note: expanded from macro '__Pyx_GetModuleGlobalName'
#        1714 |     (var) = (likely(__pyx_dict_version == __PYX_GET_DICT_VERSION(__pyx_d))) ?\
#             |              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                                                 ^
#       gensim/models/word2vec_inner.c:962:43: note: expanded from macro 'likely'
#         962 |   #define likely(x)   __builtin_expect(!!(x), 1)
#             |                                           ^
#       gensim/models/word2vec_inner.c:10852:3: error: no member named 'ma_version_tag' in 'PyDictObject'
#        10852 |   __Pyx_GetModuleGlobalName(__pyx_t_1, __pyx_n_s_fblas); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 34, __pyx_L1_error)
#              |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1714:43: note: expanded from macro '__Pyx_GetModuleGlobalName'
#        1714 |     (var) = (likely(__pyx_dict_version == __PYX_GET_DICT_VERSION(__pyx_d))) ?\
#             |              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                                                 ^
#       gensim/models/word2vec_inner.c:962:43: note: expanded from macro 'likely'
#         962 |   #define likely(x)   __builtin_expect(!!(x), 1)
#             |                                           ^
#       gensim/models/word2vec_inner.c:10947:3: error: no member named 'ma_version_tag' in 'PyDictObject'
#        10947 |   __Pyx_GetModuleGlobalName(__pyx_t_1, __pyx_n_s_init); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 960, __pyx_L1_error)
#              |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1714:43: note: expanded from macro '__Pyx_GetModuleGlobalName'
#        1714 |     (var) = (likely(__pyx_dict_version == __PYX_GET_DICT_VERSION(__pyx_d))) ?\
#             |              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                                                 ^
#       gensim/models/word2vec_inner.c:962:43: note: expanded from macro 'likely'
#         962 |   #define likely(x)   __builtin_expect(!!(x), 1)
#             |                                           ^
#       gensim/models/word2vec_inner.c:11068:53: error: no member named 'ob_digit' in 'struct _longobject'
#        11068 |         const digit* digits = ((PyLongObject*)op1)->ob_digit;
#              |                               ~~~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:11918:36: error: no member named 'curexc_traceback' in 'struct _ts'
#        11918 |         PyObject* tmp_tb = tstate->curexc_traceback;
#              |                            ~~~~~~  ^
#       gensim/models/word2vec_inner.c:11921:21: error: no member named 'curexc_traceback' in 'struct _ts'
#        11921 |             tstate->curexc_traceback = tb;
#              |             ~~~~~~  ^
#       gensim/models/word2vec_inner.c:12062:27: error: no member named 'ma_version_tag' in 'PyDictObject'
#        12062 |     return likely(dict) ? __PYX_GET_DICT_VERSION(dict) : 0;
#              |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                        ~~~~~~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:12074:36: error: no member named 'ma_version_tag' in 'PyDictObject'
#        12074 |     return (dictptr && *dictptr) ? __PYX_GET_DICT_VERSION(*dictptr) : 0;
#              |                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                        ~~~~~~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:12078:56: error: no member named 'ma_version_tag' in 'PyDictObject'
#        12078 |     if (unlikely(!dict) || unlikely(tp_dict_version != __PYX_GET_DICT_VERSION(dict)))
#              |                            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                                                 ^
#       gensim/models/word2vec_inner.c:963:43: note: expanded from macro 'unlikely'
#         963 |   #define unlikely(x) __builtin_expect(!!(x), 0)
#             |                                           ^
#       gensim/models/word2vec_inner.c:12095:5: error: no member named 'ma_version_tag' in 'PyDictObject'
#        12095 |     __PYX_UPDATE_DICT_CACHE(__pyx_d, result, *dict_cached_value, *dict_version)
#              |     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1688:21: note: expanded from macro '__PYX_UPDATE_DICT_CACHE'
#        1688 |     (version_var) = __PYX_GET_DICT_VERSION(dict);\
#             |                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                        ~~~~~~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:12176:9: error: no member named 'ma_version_tag' in 'PyDictObject'
#        12176 |         __PYX_PY_DICT_LOOKUP_IF_MODIFIED(
#              |         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        12177 |             use_cline, *cython_runtime_dict,
#              |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        12178 |             __Pyx_PyDict_GetItemStr(*cython_runtime_dict, __pyx_n_s_cline_in_traceback))
#              |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1693:16: note: expanded from macro '__PYX_PY_DICT_LOOKUP_IF_MODIFIED'
#        1693 |     if (likely(__PYX_GET_DICT_VERSION(DICT) == __pyx_dict_version)) {\
#             |         ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                                                 ^
#       gensim/models/word2vec_inner.c:962:43: note: expanded from macro 'likely'
#         962 |   #define likely(x)   __builtin_expect(!!(x), 1)
#             |                                           ^
#       gensim/models/word2vec_inner.c:12176:9: error: no member named 'ma_version_tag' in 'PyDictObject'
#        12176 |         __PYX_PY_DICT_LOOKUP_IF_MODIFIED(
#              |         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        12177 |             use_cline, *cython_runtime_dict,
#              |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        12178 |             __Pyx_PyDict_GetItemStr(*cython_runtime_dict, __pyx_n_s_cline_in_traceback))
#              |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1697:30: note: expanded from macro '__PYX_PY_DICT_LOOKUP_IF_MODIFIED'
#        1697 |         __pyx_dict_version = __PYX_GET_DICT_VERSION(DICT);\
#             |                              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:1686:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#        1686 | #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#             |                                        ~~~~~~~~~~~~~~~~~~~~~~~  ^
#       fatal error: too many errors emitted, stopping now [-ferror-limit=]
#       2 warnings and 20 errors generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for gensim
# Failed to build gensim
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> gensim
# Note: you may need to restart the kernel to use updated packages.

# %%
import gensim
from gensim.models import Word2Vec, fasttext, basemodel
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re,string  # filter the special character

# %%
sentences = [
    "The quick brown fox jumps over the lazy dog.",
    "Artificial intelligence is transforming the world we live in.",
    "Deep learning techniques have greatly improved image recognition.",
    "Natural language processing allows computers to understand human language.",
    "Data science combines statistics, computer science, and domain knowledge.",
    "The weather is nice today, perfect for a walk in the park.",
    "Cats are often seen as independent and curious creatures.",
    "The stock market fluctuates based on various economic indicators.",
    "Exploring new cuisines can be an exciting culinary adventure.",
    "Machine learning algorithms can learn from data and make predictions.",
]

# %%
cleaned_sentences = []
for sentence in sentences:
    sentence = sentence.lower()
    print(sentence)
    sentence = re.sub(r'[' + string.punctuation + ']', '', sentence)  # Remove punctuation ( $%#@!&^*().,::") 
    print(sentence)
    words = sentence.split()
    cleaned_sentences.append(words)

print(cleaned_sentences)
# Out:
# the quick brown fox jumps over the lazy dog.
# the quick brown fox jumps over the lazy dog
# artificial intelligence is transforming the world we live in.
# artificial intelligence is transforming the world we live in
# deep learning techniques have greatly improved image recognition.
# deep learning techniques have greatly improved image recognition
# natural language processing allows computers to understand human language.
# natural language processing allows computers to understand human language
# data science combines statistics, computer science, and domain knowledge.
# data science combines statistics computer science and domain knowledge
# the weather is nice today, perfect for a walk in the park.
# the weather is nice today perfect for a walk in the park
# cats are often seen as independent and curious creatures.
# cats are often seen as independent and curious creatures
# the stock market fluctuates based on various economic indicators.
# the stock market fluctuates based on various economic indicators
# exploring new cuisines can be an exciting culinary adventure.
# exploring new cuisines can be an exciting culinary adventure
# machine learning algorithms can learn from data and make predictions.
# machine learning algorithms can learn from data and make predictions
# [['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog'], ['artificial', 'intelligence', 'is', 'transforming', 'the', 'world', 'we', 'live', 'in'], ['deep', 'learning', 'techniques', 'have', 'greatly', 'improved', 'image', 'recognition'], ['natural', 'language', 'processing', 'allows', 'computers', 'to', 'understand', 'human', 'language'], ['data', 'science', 'combines', 'statistics', 'computer', 'science', 'and', 'domain', 'knowledge'], ['the', 'weather', 'is', 'nice', 'today', 'perfect', 'for', 'a', 'walk', 'in', 'the', 'park'], ['cats', 'are', 'often', 'seen', 'as', 'independent', 'and', 'curious', 'creatures'], ['the', 'stock', 'market', 'fluctuates', 'based', 'on', 'various', 'economic', 'indicators'], ['exploring', 'new', 'cuisines', 'can', 'be', 'an', 'exciting', 'culinary', 'adventure'], ['machine', 'learning', 'algorithms', 'can', 'learn', 'from', 'data', 'and', 'make', 'predictions']]

# %%
# Initialize the Word2Vec model
model = Word2Vec(sentences=cleaned_sentences, vector_size=100, window=5, min_count=1, workers=4, sg=1)

# Train the model
model.train(sentences, total_words=len(sentences), epochs=10)  # Adjust epochs according to your needs

# Save the model
model.save('word2vec_model.model')

# %%
print(model)
# Out:
# Word2Vec<vocab=79, vector_size=100, alpha=0.025>

# %%
print(model.wv['independt'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(model.wv['independt'])
#
# File ~/AITraining/AIvenv/lib/python3.11/site-packages/gensim/models/keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)    400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File ~/AITraining/AIvenv/lib/python3.11/site-packages/gensim/models/keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
#     423     """Get the key's vector, as a 1D numpy array.
#     424
#     425     Parameters
#    (...)    444
#     445     """
# --> 446     index = self.get_index(key)
#     447     if norm:
#     448         self.fill_norms()
#
# File ~/AITraining/AIvenv/lib/python3.11/site-packages/gensim/models/keyedvectors.py:420, in KeyedVectors.get_index(self, key, default)
#     418     return default
#     419 else:
# --> 420     raise KeyError(f"Key '{key}' not present")
#
# KeyError: "Key 'independt' not present"

# %%
# Get word vectors
#print(model.wv['cats'])  # Example: Vector for 'cat'

# Find similar words
similar_words = model.wv.most_similar('learning', topn=5)
#print(similar_words)
for word, similarity in similar_words:
    print(f"{word}: {similarity}")
# Out:
# are: 0.34957218170166016
# fluctuates: 0.30550336837768555
# knowledge: 0.24735164642333984
# lazy: 0.22147904336452484
# on: 0.17857569456100464

# %%
from gensim.models import FastText
from gensim.utils import simple_preprocess

# %%
model_ft = FastText(
    sentences=cleaned_sentences,
    vector_size=100,  # Desired dimensionality of word vectors
    window=5,         # Context window size
    min_count=1,      # Ignore words with frequency lower than this
    epochs=10,        # Number of training epochs
    min_n=3,          # Minimum length of character n-grams
    max_n=6           # Maximum length of character n-grams
)

# %%
print("Training complete!")

# You can save the trained model for later use
model_ft.save("fasttext.model")

# Load a saved model
# model_ft = FastText.load("fasttext.model")
# Out:
# Training complete!

# %%
print(model_ft)
# Out:
# FastText<vocab=79, vector_size=100, alpha=0.025>

# %%
# Get word vectors
print(model_ft.wv['cats'])  # Example: Vector for 'cat'

# Find similar words
similar_words = model_ft.wv.most_similar('computer', topn=5)
#print(similar_words)
for word, similarity in similar_words:
    print(f"{word}: {similarity}")
# Out:
# [-1.81109863e-04 -3.23919184e-03 -2.98799510e-04 -2.95782840e-04
#   7.74465501e-04  8.73204553e-04 -3.47495428e-03  2.57962180e-04
#   1.79446186e-03  1.24865235e-03  3.66322725e-04 -7.53869361e-04
#   1.47234381e-03  1.97704672e-03 -5.78669307e-04  5.78373496e-04
#  -2.57748854e-03  1.97880995e-03  6.82824699e-04  1.23018635e-05
#   9.02743486e-04  8.31018260e-04 -5.97956823e-04  1.02865940e-03
#   8.34737031e-04 -2.51948228e-03 -1.00764446e-04 -2.61294679e-03
#   1.12038676e-03  2.83887074e-03  2.68450659e-03  1.47404347e-03
#   6.48048765e-04  2.25037173e-03  2.89233169e-03 -4.28716978e-03
#  -2.15795255e-04 -1.08418718e-03 -1.33549713e-03 -9.48978239e-04
#  -1.44730409e-04 -1.03815075e-03  1.42869671e-04  3.40425060e-04
#  -2.35586846e-03 -1.93966829e-04  2.17532972e-03  2.30622943e-04
#   7.46831123e-04 -2.08780076e-03  7.89732614e-04 -4.32343734e-03
#   1.15050538e-03  1.69190764e-03 -2.01083696e-03  2.54766177e-03
#   1.81555888e-03  1.48110092e-03  1.52853213e-03  9.94900547e-05
#   2.87181116e-04 -4.09184489e-04 -9.69240093e-04  1.36531028e-03
#   2.00103386e-03  2.57234758e-04  1.71187264e-03 -1.19107077e-03
#   6.70754293e-04  2.65415222e-03 -2.77921441e-04 -6.90707646e-04
#   1.42376719e-03 -2.36685923e-03 -1.39429653e-03 -8.87621893e-04
#   7.33227993e-04  6.53243391e-04  2.41756369e-03 -1.58799390e-04
#  -9.77149699e-04 -9.92171350e-04  7.58425740e-04 -4.07567527e-03
#  -1.28883880e-03  1.46610022e-04  2.47568023e-05 -6.98338787e-04
#  -1.14910083e-03 -2.05825642e-03 -9.77127696e-04 -1.39949995e-03
#   1.30740937e-03  1.75405398e-03 -1.56248559e-03  1.28327729e-03
#   1.82011630e-04 -1.05963845e-03  6.46761269e-04 -2.65264680e-04]
# computers: 0.7463644742965698
# learning: 0.29301178455352783
# are: 0.22786082327365875
# combines: 0.17049665749073029
# language: 0.1669132560491562

# %%
print(model_ft.wv['brown'])
# Out:
# [ 6.6899683e-04  1.5090426e-03 -8.8849763e-04 -1.2423326e-03
#   5.1380059e-04 -1.7634614e-03  5.9120165e-04 -2.5552004e-03
#   2.8505819e-03  1.2320583e-03  5.3197274e-04 -1.7677039e-04
#  -2.0836717e-04 -3.2284842e-03 -1.2341731e-04  1.9441907e-03
#  -1.3435563e-03  1.4128465e-03 -1.3067612e-03 -1.4139424e-03
#   4.8348933e-04 -7.4332400e-04  1.0340433e-03 -6.5387040e-04
#  -3.7799173e-04  6.2503881e-04  6.7691575e-04 -2.1271415e-03
#   9.8329270e-04 -6.9750461e-04  1.5788485e-03 -1.8792505e-03
#  -3.2419271e-03 -2.4909005e-03 -9.3217078e-04 -2.0107024e-03
#   1.6659360e-03  2.4547131e-04  3.4921027e-03  2.5711050e-03
#   1.0874633e-03 -2.6961511e-03 -3.6281958e-04 -1.5031504e-03
#   9.5925492e-04 -5.8511982e-04  2.2062857e-03  1.9385517e-04
#   2.7537916e-03  1.3694788e-03 -1.3388012e-03  1.2939180e-03
#  -2.2814558e-03  1.5458089e-03  1.3685679e-03  2.5028586e-03
#   5.8458038e-05 -1.2642446e-03 -2.0274408e-03  2.3032459e-03
#   1.0547810e-03 -2.1709385e-03 -1.0554012e-03  9.8363787e-04
#   2.4780247e-03 -4.9114582e-04  1.8725505e-03 -1.6442470e-03
#  -2.4715008e-03  1.7933943e-03 -7.6845015e-04 -2.1476329e-03
#   3.1239112e-04  7.6207978e-04 -6.5708841e-04 -1.8732486e-03
#   1.3789717e-03 -1.9760137e-04 -1.1568454e-05  2.1115316e-03
#  -1.5344976e-03  1.6486844e-03 -2.0387394e-03 -3.5684831e-03
#  -1.4058972e-03  1.7432347e-03 -1.4721421e-03 -2.2909946e-04
#   1.4851892e-03  1.2635817e-03 -2.0591051e-03 -7.9501962e-04
#  -1.5489344e-03 -2.6426054e-04 -1.1202436e-03  2.8150070e-03
#  -1.1800136e-03 -2.3409126e-03 -2.2870866e-03  5.8623706e-04]

# %%
sentence1 = 'cat in the wall'
sentence2= 'the weather is cloudy today'
# Find the most similar words to 'sentence'
similar_words = model_ft.wv.most_similar(sentence2, topn=5)
print(f"Words most similar to 'sentence':\n{similar_words}\n")

# Find most similar words, even for OOV words
similar_oov = model_ft.wv.most_similar('learning computer for one year', topn=5)
print(f"Words most similar to OOV word 'anothersentenceexample':\n{similar_oov}\n")
# Out:
# Words most similar to 'sentence':
# [('the', 0.31603533029556274), ('dog', 0.2715560495853424), ('weather', 0.21614959836006165), ('today', 0.1918906569480896), ('recognition', 0.19100384414196014)]
#
# Words most similar to OOV word 'anothersentenceexample':
# [('computer', 0.48188263177871704), ('computers', 0.47151511907577515), ('learning', 0.4620915651321411), ('learn', 0.272807776927948), ('today', 0.21645088493824005)]

# %%
sentence1 = 'cat in the wall'
# Calculate the similarity between two words
similarity = model_ft.wv.similarity(sentence1, 'rat')
print(f"Similarity between 'sentence' and 'word2vec': {similarity}\n")
sentence2= 'the weather is cloudy today'
similarity_oov = model_ft.wv.similarity(sentence2, 'weather')
print(f"Similarity between 'sentence' and OOV word 'totallynewword': {similarity_oov}\n")
# Out:
# Similarity between 'sentence' and 'word2vec': 0.029605142772197723
#
# Similarity between 'sentence' and OOV word 'totallynewword': 0.21614959836006165

# %%
sim_score = model_ft.wv.similarity('man', 'human')

# %%
print(sim_score)
# Out:
# -0.103488185

# %% [markdown]
# ### Code from internet using chatgpt

# %%
from gensim.models import FastText
from gensim.test.utils import common_texts  # Example corpus
from pprint import pprint

# Example corpus (you can use your own preprocessed text data)
print("Sample corpus:")
pprint(common_texts)

# Train FastText model
model = FastText(sentences=common_texts, vector_size=100, window=5, min_count=1, workers=4, sg=1)

# Save and load the model
model.save("fasttext.model")
model = FastText.load("fasttext.model")

# Example: Get vector for a word
word_vector = model.wv['computer']
print("\nVector for 'computer':\n", word_vector)

# Find similar words
similar_words = model.wv.most_similar('computer')
print("\nWords similar to 'computer':")
pprint(similar_words)

# Handle out-of-vocabulary (OOV) word
oov_vector = model.wv['compuuter']  # misspelled
print("\nVector for misspelled 'compuuter':\n", oov_vector)
# Out:
# Sample corpus:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]
#
# Vector for 'computer':
#  [ 2.96936167e-04  3.31060466e-04 -8.77768325e-04  3.39444174e-04
#  -5.01747418e-04 -2.04214524e-03 -1.24066719e-03 -1.94044539e-03
#   1.34510931e-03 -2.41268426e-03  9.18505422e-04 -1.03151030e-03
#  -7.63410062e-04  7.31222244e-05  1.38286629e-03  5.19435504e-04
#  -2.98849802e-04 -1.19464763e-03 -1.17238448e-03 -6.08951552e-04
#  -6.78338984e-04  3.92779708e-04  9.88251195e-05  8.12689308e-04
#   5.81971311e-04  7.01953366e-04 -7.36806658e-04 -1.03962549e-03
#  -6.25258312e-04 -2.40496884e-04 -1.19316357e-03 -2.65940849e-04
#   7.36046524e-04 -7.21505727e-04 -1.27508014e-03  1.24231781e-04
#   3.77583550e-04 -1.33155228e-03 -2.73441360e-03 -3.04829708e-04
#   9.28272377e-04 -7.28168816e-04 -1.12919568e-03 -3.21931177e-04
#  -2.06016310e-04 -1.04854174e-04 -6.22976047e-04 -1.61377620e-03
#   9.91107081e-04  9.22983818e-05  3.68000241e-04 -5.37839776e-04
#   1.13322982e-03  8.70750577e-04 -1.63867278e-03 -8.55855411e-04
#  -6.31069415e-04  6.22909865e-04  8.40167049e-04 -1.12830219e-03
#   1.29163847e-03 -3.40488943e-04 -1.17833621e-03 -1.60850491e-03
#   1.52693118e-03  3.01169712e-05 -2.41883954e-05 -7.27596227e-04
#   1.73330551e-03  8.93421762e-04  3.26789886e-04 -4.63379052e-04
#  -2.31358409e-03 -1.72005536e-03  4.35937254e-04 -4.12225461e-04
#  -1.06689101e-03 -1.00902386e-03 -1.64344837e-03 -1.05065810e-04
#   1.01913651e-03 -6.24372798e-04 -1.08174444e-03  8.85603193e-04
#  -1.45729631e-03  6.48391724e-04  4.41413518e-04 -1.24500669e-03
#   3.49245267e-04 -9.81050660e-04 -9.73784481e-04 -1.98150854e-04
#  -1.89508792e-04 -9.85311344e-04  5.74433478e-04  1.99000956e-03
#   7.19957534e-05  9.95708513e-04 -1.70885876e-03  1.34901761e-03]
#
# Words similar to 'computer':
# [('user', 0.15659411251544952),
#  ('response', 0.12383825331926346),
#  ('eps', 0.030704928562045097),
#  ('system', 0.025573885068297386),
#  ('interface', 0.005858757067471743),
#  ('survey', -0.03156975656747818),
#  ('minors', -0.054556481540203094),
#  ('human', -0.0668589174747467),
#  ('time', -0.06855935603380203),
#  ('trees', -0.10636083036661148)]
#
# Vector for misspelled 'compuuter':
#  [ 5.37822256e-04  8.13040300e-04  2.86898983e-04  3.45453183e-04
#  -3.63900501e-04 -8.91792006e-04 -1.07653148e-03 -2.65255850e-03
#   1.23973237e-03 -1.08289874e-04 -2.04619173e-05  2.71872792e-04
#  -2.53348146e-03  7.76573201e-04  1.85995072e-04 -5.25655982e-04
#   1.37992043e-04 -7.77879613e-04 -2.20079767e-03 -1.84260149e-04
#  -8.84888927e-04  1.64963049e-03 -1.51548896e-03  5.80495223e-04
#   1.09000551e-03  1.43722841e-03 -1.90578937e-03 -1.08204995e-05
#   1.39688689e-03  4.18723939e-04 -5.09811915e-04  3.11804877e-04
#   1.97143061e-03 -1.47492683e-03  3.38606245e-04  1.16263342e-03
#   1.47270760e-03 -2.10537040e-03 -1.75831176e-03 -5.03999298e-04
#   1.76466804e-03 -5.19507390e-04  6.85872510e-04 -6.02523971e-04
#  -9.15401499e-04  3.57487297e-04 -7.29428371e-04 -7.87281024e-04
#   2.02886132e-03  7.51795247e-04 -6.72323658e-05 -2.23634779e-04
#   8.76179023e-04 -1.69347040e-04 -1.35133113e-03 -4.21586767e-04
#  -8.60555796e-04  8.67682174e-05  4.87919751e-04 -3.50769697e-04
#  -2.90343378e-05  3.78279947e-06 -1.79809600e-03 -4.29539912e-04
#   7.47438404e-04 -8.46476876e-04  6.62479666e-04 -3.10997275e-04
#   1.32820650e-03  3.53045383e-04  9.22459993e-04 -1.75035582e-03
#  -2.05549225e-03 -2.05196161e-03 -4.94325242e-04 -1.68996560e-03
#  -1.81310592e-04  1.12795166e-03 -3.06170114e-04  4.14203969e-04
#  -9.85328807e-04 -1.28988875e-03 -1.31777677e-04  1.69355806e-03
#  -1.16845162e-03  1.16397394e-03 -4.07498825e-04 -1.70077092e-03
#   1.18601054e-03 -5.72660065e-04 -5.10007318e-04 -1.17064337e-03
#  -1.07545615e-03 -2.10420322e-03 -2.11223465e-04  2.40667001e-03
#  -6.50291971e-04 -1.95746412e-04 -6.48648303e-04  1.95697858e-03]
